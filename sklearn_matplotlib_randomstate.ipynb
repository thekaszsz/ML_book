# %% [markdown]
# <a href="https://colab.research.google.com/github/thekaszsz/ML_book/blob/main/sklearn_matplotlib_randomstate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 매개변수를 지정해서 가상의 샘플 데이터를 자동으로 생성하기

# %% [markdown]
# 랜덤 시드를 3으로 지정, 특징량 2, 클러스터 수 2, 표준 편자 1인 300개의 점으로 된 데이터 세트 만들기

# %%
from sklearn.datasets import make_blobs
import pandas as pd

X, y = make_blobs(
    random_state = 3, #랜덤 시드 3
    n_features = 2, #특징량 2
    centers = 2, #클러스터 2
    cluster_std = 1, #표준편차 1
    n_samples = 300 #개수 300
)

# %% [markdown]
# 특징량(X)로 데이터 프레임을 만들고, 분류(y)를 target 열로 추가하기

# %%
df = pd.DataFrame(X)
df['target'] = y
df.head()
# Out:
#           0         1  target
# 0 -5.071794 -1.364393       1
# 1 -3.174364 -1.145104       1
# 2  0.818543  5.937601       0
# 3 -4.338424 -2.055692       1
# 4 -3.887373 -0.436586       1

# %%
import matplotlib.pyplot as plt

#분류에 따라 각각의 데이터 프레임으로 나눈다
df0 = df[df["target"] == 0]
df1 = df[df["target"] == 1]

#분류 0은 파랑색, 분류 1은 빨강색으로 산포도를 그린다
plt.figure(figsize = (5,5))
plt.scatter(df0[0], df0[1], color = "b", alpha = 0.5)
plt.scatter(df1[0], df1[1], color = "r", alpha = 0.5)
plt.grid()
plt.show()

# %% [markdown]
# 클러스터가 3개인 데이터 만들기

# %%
X, y = make_blobs(
    random_state = 3,
    n_features = 2,
    centers = 3,
    cluster_std = 1,
    n_samples = 300
)

# %%
df = pd.DataFrame(X)
df['target'] = y
df.head()
# Out:
#           0         1  target
# 0  6.969050  6.344916       2
# 1  8.866481  6.564206       2
# 2  0.818543  5.937601       0
# 3 -4.338424 -2.055692       1
# 4  8.153471  7.272724       2

# %%
df0 = df[df['target'] == 0]
df1 = df[df['target'] == 1]
df2 = df[df['target'] == 2]

# %%
plt.figure(figsize = (5,5))
plt.scatter(df0[0], df0[1], color = 'b', alpha = 0.5)
plt.scatter(df1[0], df1[1], color = 'r', alpha = 0.5)
plt.scatter(df2[0], df2[1], color = 'g', alpha = 0.5)
plt.show()

# %% [markdown]
# 이외에 초승달 모양, 이중원, 동심원, 회귀선의 모형으로도 나타낼 수 있다

# %% [markdown]
# 초승달: make_moons
# 이중원: make_circles
# 동심원: make_gaussian_quantiles
# 회귀선: make_regression
