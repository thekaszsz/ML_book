# %% [markdown]
# <a href="https://colab.research.google.com/github/thekaszsz/ML_book/blob/main/bigdata_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/data100/mtcars.csv')
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
Q1 = df['mpg'].quantile(0.25)
print(round(Q1))
# Out:
# 15

# %%
result = df[['mpg']][df['mpg'].between(19,21)].count()
print(result)
# Out:
# mpg    5
# dtype: int64

# %%
Q1 = df['hp'].quantile(0.25)
Q3 = df['hp'].quantile(0.75)
IQR = Q3-Q1
print(abs(IQR))
# Out:
# 83.5

# %%
result = df.sort_values('wt', ascending = False)
result2 = sum(result['wt'].head(10))
print(int(result2))
# Out:
# 42

# %%
len_6 = len(df[['cyl']][df['cyl'] == 6])
len_tot = len(df)
print(round(len_6/len_tot, 1))
# Out:
# 0.2

# %%
mpg_10 = df['mpg'].head(10)
mpg_mean = mpg_10.mean()
print(round(mpg_mean))
# Out:
# 20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
p50 = int(len(df)*0.5)
df50 = df[:p50]
print(df50['wt'].median())
# Out:
# 3.44

# %%
df = pd.DataFrame({
    '날짜': ['20220103','20220105',None,'20230127',"20220203","20220205","20230210","20230223","20230312",'20230422','20220505','20230511'],
    '제품': ['A','B',None,'B','A',None,'A','B','A','B','A','A'],
    '판매수': [3,None,5,10,10,10,15,15,20,None,30,40],
    '개당수익': [300,400,500,600,400,500,500,600,600,700,600,600]})

# %%
df
# Out:
#           날짜    제품   판매수  개당수익
# 0   20220103     A   3.0   300
# 1   20220105     B   NaN   400
# 2       None  None   5.0   500
# 3   20230127     B  10.0   600
# 4   20220203     A  10.0   400
# 5   20220205  None  10.0   500
# 6   20230210     A  15.0   500
# 7   20230223     B  15.0   600
# 8   20230312     A  20.0   600
# 9   20230422     B   NaN   700
# 10  20220505     A  30.0   600
# 11  20230511     A  40.0   600

# %%
isnull = df.isnull().sum()
print(isnull.sum())
# Out:
# 5

# %%
median = df['판매수'].median()
median
df['판매수'] = df['판매수'].fillna(median)
mean = df['판매수'].mean()
print(round(mean))
# Out:
# 15

# %%
df = pd.DataFrame({
    '날짜': ['20220103','20220105',None,'20230127',"20220203","20220205","20230210","20230223","20230312",'20230422','20220505','20230511'],
    '제품': ['A','B',None,'B','A',None,'A','B','A','B','A','A'],
    '판매수': [3,None,5,10,10,10,15,15,20,None,30,40],
    '개당수익': [300,400,500,600,400,500,500,600,600,700,600,600]})


df = df['판매수'].dropna()

# %%
df2 = int(len(df)*0.5)
df3 = df[:df2]
Q1 = df3.quantile(0.25)
print(round(Q1))
# Out:
# 5

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/data100/mtcars.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
cyl_4 = df[['mpg']][df['cyl'] == 4].mean()
cyl_6 = df[['mpg']][df['cyl'] == 6].mean()
result = cyl_4-cyl_6
print(round(abs(result)))
# Out:
# mpg    7.0
# dtype: float64

# %%
#Z-SCORE은 나중에 문제 12번

# %%
#최소최대도 나중에 문제 13번

# %%
Q1 = df['wt'].quantile(0.25)
Q3 = df['wt'].quantile(0.75)
IQR = Q3-Q1

upper = Q3+1.5*IQR
lower = Q1-1.5*IQR

cond1 = (df['wt']>upper)
cond2 = (df['wt']<lower)

print(len(df[cond1]) + len(df[cond2]))
# Out:
# 3

# %%
df = pd.DataFrame({
    '날짜': ['20220103','20220105',None,'20230127',"20220203","20220205","20230210","20230223","20230312",'20230422','20220505','20230511'],
    '제품': ['A','B',None,'B','A',None,'A','B','A','B','A','A'],
    '판매수': [3,None,5,10,10,10,15,15,20,None,30,40],
    '개당수익': [300,400,500,600,400,500,500,600,600,700,600,600]})

# %%
cond1 = df['판매수'].mean()

mini = df['판매수'].min()
min = df['판매수'].fillna(mini)
cond2 = min.mean()

print(round(abs(cond1-cond2)))

#copy()를 써서 복제한 후 변수에 넣어서 사용하도록 하자
# Out:
# 2

# %%
df = pd.read_csv('/content/drive/MyDrive/data100/mtcars.csv')

# %%
df = df[:][df['vs']!=0]
df = df.sort_values('mpg',ascending = False)
print(df['hp'].iloc[0])
# Out:
# 65

# %%
df = pd.read_csv('/content/drive/MyDrive/data100/mtcars.csv')

# %%
gear_3 = df[['hp']][df['gear'] == 3]
gear_4 = df[['hp']][df['gear'] == 4]

std3 = gear_3.std()
std4 = gear_4.std()

print(round(abs(std3-std4), 1))
# Out:
# hp    21.8
# dtype: float64

# %%
mean = df.groupby('gear')['mpg'].mean()

result = df[['mpg']][df['gear'] == 4]
Q3 = result.quantile(0.75)
print(Q3)
# Out:
# mpg    28.075
# Name: 0.75, dtype: float64

# %%
#문제 19번

# %%
df = pd.read_csv('/content/drive/MyDrive/data100/mtcars.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#문제 20번
df[['mpg']][df['Unnamed: 0'].isin(['Merc'])]
# Out:
# Empty DataFrame
# Columns: [mpg]
# Index: []

# %%
df = pd.DataFrame({
    '날짜': ['20220103','20220105','20230105','20230127',"20220203","20220205","20230210","20230223","20230312",'20230422','20220505','20230511'],
    '제품': ['A','B','A','B','A','B','A','B','A','B','A','A'],
    '판매수': [3,5,5,10,10,10,15,15,20,25,30,40],
    '개당수익': [300,400,500,600,400,500,500,600,600,700,600,600]})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      12 non-null     object
#  1   제품      12 non-null     object
#  2   판매수     12 non-null     int64
#  3   개당수익    12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 512.0+ bytes

# %%
df['날짜'] = pd.to_datetime(df['날짜'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      12 non-null     datetime64[ns]
#  1   제품      12 non-null     object
#  2   판매수     12 non-null     int64
#  3   개당수익    12 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 512.0+ bytes

# %%
first = df[df['날짜'].between('2022-01-01','2022-03-31')]
sell = first['판매수']*first['개당수익']
print(sell.sum())
# Out:
# 11900

# %%
first_2022 = df[df['날짜'].between('2022-01-01','2022-12-31')]
sell_2022 = first_2022['판매수']*first_2022['개당수익']
fin_2022 = sell_2022.sum()

first_2023 = df[df['날짜'].between('2023-01-01','2023-12-31')]
sell_2023 = first_2023['판매수']*first_2023['개당수익']
fin_2023 = sell_2023.sum()

print(abs(fin_2022-fin_2023))
# Out:
# 48600

# %%
df['year'] = df['날짜'].dt.year
df
# Out:
#            날짜 제품  판매수  개당수익  year
# 0  2022-01-03  A    3   300  2022
# 1  2022-01-05  B    5   400  2022
# 2  2023-01-05  A    5   500  2023
# 3  2023-01-27  B   10   600  2023
# 4  2022-02-03  A   10   400  2022
# 5  2022-02-05  B   10   500  2022
# 6  2023-02-10  A   15   500  2023
# 7  2023-02-23  B   15   600  2023
# 8  2023-03-12  A   20   600  2023
# 9  2023-04-22  B   25   700  2023
# 10 2022-05-05  A   30   600  2022
# 11 2023-05-11  A   40   600  2023

# %%
df1 = df.copy()
df1
# Out:
#            날짜 제품  판매수  개당수익  year
# 0  2022-01-03  A    3   300  2022
# 1  2022-01-05  B    5   400  2022
# 2  2023-01-05  A    5   500  2023
# 3  2023-01-27  B   10   600  2023
# 4  2022-02-03  A   10   400  2022
# 5  2022-02-05  B   10   500  2022
# 6  2023-02-10  A   15   500  2023
# 7  2023-02-23  B   15   600  2023
# 8  2023-03-12  A   20   600  2023
# 9  2023-04-22  B   25   700  2023
# 10 2022-05-05  A   30   600  2022
# 11 2023-05-11  A   40   600  2023

# %%
df1 = df1[:][df1['year'] == 2023]
df1
# Out:
#            날짜 제품  판매수  개당수익  year
# 2  2023-01-05  A    5   500  2023
# 3  2023-01-27  B   10   600  2023
# 6  2023-02-10  A   15   500  2023
# 7  2023-02-23  B   15   600  2023
# 8  2023-03-12  A   20   600  2023
# 9  2023-04-22  B   25   700  2023
# 11 2023-05-11  A   40   600  2023

# %%
df1['매출액'] = df1['판매수']*df1['개당수익']

asum = df1['매출액'][df1['제품'] == 'A'].sum()
print(asum)
bsum = df1['매출액'][df1['제품'] == 'B'].sum()
print(bsum)
# Out:
# 46000
# 32500

# %%
asell = df1['판매수'][df1['제품'] == 'A'].sum()
print(asell)
# Out:
# 80

# %%
# Out:
#            날짜 제품  판매수  개당수익  year
# 0  2022-01-03  A    3   300  2022
# 1  2022-01-05  B    5   400  2022
# 2  2023-01-05  A    5   500  2023
# 3  2023-01-27  B   10   600  2023
# 4  2022-02-03  A   10   400  2022
# 5  2022-02-05  B   10   500  2022
# 6  2023-02-10  A   15   500  2023
# 7  2023-02-23  B   15   600  2023
# 8  2023-03-12  A   20   600  2023
# 9  2023-04-22  B   25   700  2023
# 10 2022-05-05  A   30   600  2022
# 11 2023-05-11  A   40   600  2023

# %%
df = pd.DataFrame({
    '날짜': ['20220103','20220105','20230105','20230127',"20220203","20220205","20230210","20230223","20230312",'20230422','20220505','20230511'],
    '제품': ['A','B','A','B','A','B','A','B','A','B','A','A'],
    '판매수': [3,5,5,10,10,10,15,15,20,25,30,40],
    '개당수익': [300,400,500,600,400,500,500,600,600,700,600,600]})

# %%
df['매출액'] = df['판매수']*df['개당수익']
df
# Out:
#           날짜 제품  판매수  개당수익    매출액
# 0   20220103  A    3   300    900
# 1   20220105  B    5   400   2000
# 2   20230105  A    5   500   2500
# 3   20230127  B   10   600   6000
# 4   20220203  A   10   400   4000
# 5   20220205  B   10   500   5000
# 6   20230210  A   15   500   7500
# 7   20230223  B   15   600   9000
# 8   20230312  A   20   600  12000
# 9   20230422  B   25   700  17500
# 10  20220505  A   30   600  18000
# 11  20230511  A   40   600  24000

# %%
cond1 = (df['매출액'] > 4000)
cond2 = (df['매출액'] < 10000)
df = df [cond1&cond2]
print(len(df))
# Out:
# 4

# %%
df = pd.DataFrame({
    '물품': ['A','B','A','B','A','B','A'],
    '판매수': [5,10,15,15,20,25,40],
    '개당수익': [500,600,500,600,600,700,600]})
time = pd.date_range('2023-09-24 12:25:00', '2023-09-25 14:45:30', periods = 7)
df['time']=time
df = df[['time', '물품', '판매수', '개당수익']]
df
# Out:
#                  time 물품  판매수  개당수익
# 0 2023-09-24 12:25:00  A    5   500
# 1 2023-09-24 16:48:25  B   10   600
# 2 2023-09-24 21:11:50  A   15   500
# 3 2023-09-25 01:35:15  B   15   600
# 4 2023-09-25 05:58:40  A   20   600
# 5 2023-09-25 10:22:05  B   25   700
# 6 2023-09-25 14:45:30  A   40   600

# %%
df[['판매수']][df['time'].between('2023-09-24 16:00:00', '2023-09-24 22:00:00')].sum()
# Out:
# 판매수    25
# dtype: int64

# %%
df = pd.DataFrame({
    '물품': ['A','B','A','B','A','B','A'],
    '판매수': [5,10,15,15,20,25,40],
    '개당수익': [500,600,500,600,600,700,600]})
time = pd.date_range('2023-09-24 12:25:00', '2023-09-25 14:45:30', periods = 7)
df['time']=time
df = df[['time', '물품', '판매수', '개당수익']]
df = df.set_index('time',drop = True)
df
# Out:
#                     물품  판매수  개당수익
# time
# 2023-09-24 12:25:00  A    5   500
# 2023-09-24 16:48:25  B   10   600
# 2023-09-24 21:11:50  A   15   500
# 2023-09-25 01:35:15  B   15   600
# 2023-09-25 05:58:40  A   20   600
# 2023-09-25 10:22:05  B   25   700
# 2023-09-25 14:45:30  A   40   600

# %%
df['매출액'] = df['판매수']*df['개당수익']
df = df.reset_index() #index를 column으로 초기화

# %%
df = df[:][df['물품'] == 'B']
df[['매출액']][df['time'].between('2023-09-25 00:00:00', '2023-09-25 12:00:00')].sum()
# Out:
# 매출액    26500
# dtype: int64

# %%
df = pd.DataFrame({
    '물품': ['A','B','A','B','A','B','A'],
    '판매수': [5,10,15,15,20,25,40],
    '개당수익': [500,600,500,600,600,700,600]})
time = pd.date_range('2023-09-24 12:25:00', '2023-09-25 14:45:30', periods = 7)
df['time']=time
df = df[['time', '물품', '판매수', '개당수익']]
df = df.set_index('time',drop = True)
df
# Out:
#                     물품  판매수  개당수익
# time
# 2023-09-24 12:25:00  A    5   500
# 2023-09-24 16:48:25  B   10   600
# 2023-09-24 21:11:50  A   15   500
# 2023-09-25 01:35:15  B   15   600
# 2023-09-25 05:58:40  A   20   600
# 2023-09-25 10:22:05  B   25   700
# 2023-09-25 14:45:30  A   40   600

# %%
df['매출액'] = df['판매수']*df['개당수익']
df = df.reset_index()
df
# Out:
#                  time 물품  판매수  개당수익    매출액
# 0 2023-09-24 12:25:00  A    5   500   2500
# 1 2023-09-24 16:48:25  B   10   600   6000
# 2 2023-09-24 21:11:50  A   15   500   7500
# 3 2023-09-25 01:35:15  B   15   600   9000
# 4 2023-09-25 05:58:40  A   20   600  12000
# 5 2023-09-25 10:22:05  B   25   700  17500
# 6 2023-09-25 14:45:30  A   40   600  24000

# %%
df = df[:][df['물품'] == 'A']

df[['매출액']][df['time'].between('2023-09-24 12:00:00', '2023-09-24 23:59:59')].sum()
# Out:
# 매출액    10000
# dtype: int64
