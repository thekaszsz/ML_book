# %% [markdown]
# <a href="https://colab.research.google.com/github/thekaszsz/ML_book/blob/main/bigdata_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
emp = pd.read_csv("/content/drive/MyDrive/data100/emp.csv")
emp
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  1981-11-17  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  1981-05-09  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  1981-04-01  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-10  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-11  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  1981-08-21  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  1981-12-11   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  1981-02-23  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  1981-12-11  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  1980-12-09   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1982-12-22  3000     NaN      20
# 12   7876   ADAMS      CLERK  7788.0  1983-01-15  1100     NaN      20
# 13   7934  MILLER      CLERK  7782.0  1982-01-11  1300     NaN      10

# %%
emp = pd.read_csv("/content/drive/MyDrive/data100/emp.csv")
emp[ ['empno','ename','sal','job']]
# Out:
#     empno   ename   sal        job
# 0    7839    KING  5000  PRESIDENT
# 1    7698   BLAKE  2850    MANAGER
# 2    7782   CLARK  2450    MANAGER
# 3    7566   JONES  2975    MANAGER
# 4    7654  MARTIN  1250   SALESMAN
# 5    7499   ALLEN  1600   SALESMAN
# 6    7844  TURNER  1500   SALESMAN
# 7    7900   JAMES   950      CLERK
# 8    7521    WARD  1250   SALESMAN
# 9    7902    FORD  3000    ANALYST
# 10   7369   SMITH   800      CLERK
# 11   7788   SCOTT  3000    ANALYST
# 12   7876   ADAMS  1100      CLERK
# 13   7934  MILLER  1300      CLERK

# %%
emp[['ename','sal','job']][emp['job'] == 'SALESMAN']
# Out:
#     ename   sal       job
# 4  MARTIN  1250  SALESMAN
# 5   ALLEN  1600  SALESMAN
# 6  TURNER  1500  SALESMAN
# 8    WARD  1250  SALESMAN

# %%
emp[['ename','sal','job']][emp['sal'] >= 1200]
# Out:
#      ename   sal        job
# 0     KING  5000  PRESIDENT
# 1    BLAKE  2850    MANAGER
# 2    CLARK  2450    MANAGER
# 3    JONES  2975    MANAGER
# 4   MARTIN  1250   SALESMAN
# 5    ALLEN  1600   SALESMAN
# 6   TURNER  1500   SALESMAN
# 8     WARD  1250   SALESMAN
# 9     FORD  3000    ANALYST
# 11   SCOTT  3000    ANALYST
# 13  MILLER  1300      CLERK

# %%
emp[['ename', 'sal', 'deptno']][emp['deptno'] == 20]
# Out:
#     ename   sal  deptno
# 3   JONES  2975      20
# 9    FORD  3000      20
# 10  SMITH   800      20
# 11  SCOTT  3000      20
# 12  ADAMS  1100      20

# %%
emp[['ename','sal']][emp['sal'].between(1000, 3000)]
# Out:
#      ename   sal
# 1    BLAKE  2850
# 2    CLARK  2450
# 3    JONES  2975
# 4   MARTIN  1250
# 5    ALLEN  1600
# 6   TURNER  1500
# 8     WARD  1250
# 9     FORD  3000
# 11   SCOTT  3000
# 12   ADAMS  1100
# 13  MILLER  1300

# %%
emp[['ename','sal']][~ emp['sal'].between(1000,3000)]
# Out:
#     ename   sal
# 0    KING  5000
# 7   JAMES   950
# 10  SMITH   800

# %%
import pandas as pd

boston = pd.read_csv("/content/drive/MyDrive/data100/boston.csv")
boston
# Out:
#       id     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1      1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2      2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3      3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4      4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 15 columns]

# %%
boston[['id','price']][boston['price'].between(10,30)]
# Out:
#       id  price
# 0      0   24.0
# 1      1   21.6
# 5      5   28.7
# 6      6   22.9
# 7      7   27.1
# ..   ...    ...
# 501  501   22.4
# 502  502   20.6
# 503  503   23.9
# 504  504   22.0
# 505  505   11.9
#
# [398 rows x 2 columns]

# %%
boston[:][boston['price'].between(10,30)]
# Out:
#       id     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1      1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 5      5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# 6      6  0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605  5.0  311.0
# 7      7  0.14455  12.5   7.87   0.0  0.524  6.172  96.1  5.9505  5.0  311.0
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 5       18.7  394.12   5.21   28.7
# 6       15.2  395.60  12.43   22.9
# 7       15.2  396.90  19.15   27.1
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [398 rows x 15 columns]

# %%
boston[:][~ boston['price'].between(10,30)]
# Out:
#       id      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 2      2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0
# 3      3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0
# 4      4   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0
# 39    39   0.02763  75.0   2.95   0.0  0.428  6.595   21.8  5.4011   3.0
# 40    40   0.03359  75.0   2.95   0.0  0.428  7.024   15.8  5.4011   3.0
# ..   ...       ...   ...    ...   ...    ...    ...    ...     ...   ...
# 436  436  14.42080   0.0  18.10   0.0  0.740  6.461   93.3  2.0026  24.0
# 437  437  15.17720   0.0  18.10   0.0  0.740  6.152  100.0  1.9142  24.0
# 438  438  13.67810   0.0  18.10   0.0  0.740  5.935   87.9  1.8206  24.0
# 489  489   0.18337   0.0  27.74   0.0  0.609  5.414   98.3  1.7554   4.0
# 490  490   0.20746   0.0  27.74   0.0  0.609  5.093   98.0  1.8226   4.0
#
#        TAX  PTRATIO       B  LSTAT  price
# 2    242.0     17.8  392.83   4.03   34.7
# 3    222.0     18.7  394.63   2.94   33.4
# 4    222.0     18.7  396.90   5.33   36.2
# 39   252.0     18.3  395.63   4.32   30.8
# 40   252.0     18.3  395.62   1.98   34.9
# ..     ...      ...     ...    ...    ...
# 436  666.0     20.2   27.49  18.05    9.6
# 437  666.0     20.2    9.32  26.45    8.7
# 438  666.0     20.2   68.95  34.02    8.4
# 489  711.0     20.1  344.05  23.97    7.0
# 490  711.0     20.1  318.43  29.68    8.1
#
# [108 rows x 15 columns]

# %%
import pandas as pd

emp20 = pd.read_csv("/content/drive/MyDrive/data100/emp20.csv", encoding = 'euckr')
emp20
# Out:
#     empno ename  age telecom   major   address
# 0       1   홍길동   31      kt    경영학과    인천시 서구
# 1       2   이순신   28      sk  독어독문학과   서울시 양천구
# 2       3   정약용   29      sk    경제학과   서울시 마포구
# 3       4   김유신   31      sk     수학과   경기도 화성시
# 4       5   장보고   25      kt  국제관계학과   경기도 하남시
# 5       6   정몽주   34      sk  컴퓨터공학과   경기도 성남시
# 6       7   문익점   35      sk    행정학과   서울시 용산구
# 7       8    황희   30      sk   중국어학과   서울시 도봉구
# 8       9   한석봉   35      sk    물리학과   경기도 부천시
# 9      10   황진이   27      sk    행정학과   경기도 안산시
# 10     11   안중근   26      kt    경영학과   서울시 관악구
# 11     12   김옥균   30      sk    경영학과   서울시 서초구
# 12     13   윤동주   26      kt  컴퓨터정보과   서울시 서초구
# 13     14   안창호   28      sk    유아교육   서울시 서초구
# 14     15   김좌진   25      sk  정보전기전자   서울시 중랑구
# 15     16   김두한   26      sk    의상학과   서울시 송파구
# 16     17    논개   30      kt     사학과   서울시 강서구
# 17     18    최영   31      kt   생명공학과   경기도 안성시
# 18     19   김부식   33      kt    건축학과  경기도 성남시
# 19     20   장영실   33      lg  지적정보학과  경기도 성남시
# 20     21   김홍도   37      sk  문화콘텐츠과   경기도 하남시

# %%
emp20[['ename','age']][emp20['age'].between(20,29)]
# Out:
#    ename  age
# 1    이순신   28
# 2    정약용   29
# 4    장보고   25
# 9    황진이   27
# 10   안중근   26
# 12   윤동주   26
# 13   안창호   28
# 14   김좌진   25
# 15   김두한   26

# %%
emp[['ename','job']][emp['job'].isin(['SALESMAN','ANALYST'])]
# Out:
#      ename       job
# 4   MARTIN  SALESMAN
# 5    ALLEN  SALESMAN
# 6   TURNER  SALESMAN
# 8     WARD  SALESMAN
# 9     FORD   ANALYST
# 11   SCOTT   ANALYST

# %%
emp20[['ename','telecom']][emp20['telecom'].isin(['kt','lg'])]
# Out:
#    ename telecom
# 0    홍길동      kt
# 4    장보고      kt
# 10   안중근      kt
# 12   윤동주      kt
# 16    논개      kt
# 17    최영      kt
# 18   김부식      kt
# 19   장영실      lg

# %%
emp20[['ename','telecom']][~emp20['telecom'].isin(['kt','lg'])]
# Out:
#    ename telecom
# 1    이순신      sk
# 2    정약용      sk
# 3    김유신      sk
# 5    정몽주      sk
# 6    문익점      sk
# 7     황희      sk
# 8    한석봉      sk
# 9    황진이      sk
# 11   김옥균      sk
# 13   안창호      sk
# 14   김좌진      sk
# 15   김두한      sk
# 20   김홍도      sk

# %%
emp[['ename','comm']][emp['comm'].isnull()]
# Out:
#      ename  comm
# 0     KING   NaN
# 1    BLAKE   NaN
# 2    CLARK   NaN
# 3    JONES   NaN
# 7    JAMES   NaN
# 9     FORD   NaN
# 10   SMITH   NaN
# 11   SCOTT   NaN
# 12   ADAMS   NaN
# 13  MILLER   NaN

# %%
emp[['ename','comm']][~emp['comm'].isnull()]
# Out:
#     ename    comm
# 4  MARTIN  1400.0
# 5   ALLEN   300.0
# 6  TURNER     0.0
# 8    WARD   500.0

# %%
emp[['ename']][emp['ename'].apply(lambda x:x[1] == 'M')]
# Out:
#     ename
# 10  SMITH

# %%
emp[['ename','sal']][emp['ename'].apply(lambda x:x[-1] == "T")]
# Out:
#     ename   sal
# 11  SCOTT  3000

# %%
emp20[['ename','age']][emp20['ename'].apply(lambda x:x[0] == '김')]
# Out:
#    ename  age
# 3    김유신   31
# 11   김옥균   30
# 14   김좌진   25
# 15   김두한   26
# 18   김부식   33
# 20   김홍도   37

# %%
emp20[['ename','age']][~emp20['ename'].apply(lambda x:x[0] == '김')]
# Out:
#    ename  age
# 0    홍길동   31
# 1    이순신   28
# 2    정약용   29
# 4    장보고   25
# 5    정몽주   34
# 6    문익점   35
# 7     황희   30
# 8    한석봉   35
# 9    황진이   27
# 10   안중근   26
# 12   윤동주   26
# 13   안창호   28
# 16    논개   30
# 17    최영   31
# 19   장영실   33

# %%
emp[['ename','sal']].sort_values(by='sal',ascending =False).head()
# Out:
#     ename   sal
# 0    KING  5000
# 9    FORD  3000
# 11  SCOTT  3000
# 3   JONES  2975
# 1   BLAKE  2850

# %%
emp[['ename','sal','job']][emp['job']=='SALESMAN'].sort_values(by = 'sal', ascending = False)
# Out:
#     ename   sal       job
# 5   ALLEN  1600  SALESMAN
# 6  TURNER  1500  SALESMAN
# 4  MARTIN  1250  SALESMAN
# 8    WARD  1250  SALESMAN

# %%
emp20[['ename','age','telecom']][emp20['telecom'] != 'kt'].sort_values(by = 'age',ascending = False)
# Out:
#    ename  age telecom
# 20   김홍도   37      sk
# 6    문익점   35      sk
# 8    한석봉   35      sk
# 5    정몽주   34      sk
# 19   장영실   33      lg
# 3    김유신   31      sk
# 7     황희   30      sk
# 11   김옥균   30      sk
# 2    정약용   29      sk
# 1    이순신   28      sk
# 13   안창호   28      sk
# 9    황진이   27      sk
# 15   김두한   26      sk
# 14   김좌진   25      sk

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       13 non-null     float64
#  4   hiredate  14 non-null     object
#  5   sal       14 non-null     int64
#  6   comm      4 non-null      float64
#  7   deptno    14 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.0+ KB

# %%
emp['hiredate'] = pd.to_datetime(emp['hiredate'])
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       13 non-null     float64
#  4   hiredate  14 non-null     datetime64[ns]
#  5   sal       14 non-null     int64
#  6   comm      4 non-null      float64
#  7   deptno    14 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.0+ KB

# %%
emp[['ename','hiredate']][emp['hiredate'].isin(['81-11-17'])]
# Out:
#   ename   hiredate
# 0  KING 1981-11-17

# %%
emp[['ename','hiredate']][emp['hiredate'].between('1981-01-01','1989-12-31')]
# Out:
#      ename   hiredate
# 0     KING 1981-11-17
# 1    BLAKE 1981-05-01
# 2    CLARK 1981-05-09
# 3    JONES 1981-04-01
# 4   MARTIN 1981-09-10
# 5    ALLEN 1981-02-11
# 6   TURNER 1981-08-21
# 7    JAMES 1981-12-11
# 8     WARD 1981-02-23
# 9     FORD 1981-12-11
# 11   SCOTT 1982-12-22
# 12   ADAMS 1983-01-15
# 13  MILLER 1982-01-11

# %%
emp[['ename','job','hiredate']][emp['job'] == 'SALESMAN'][emp['hiredate'].between('1981-01-01','1981-12-31')]
# Out:
# <ipython-input-32-8598a70e5f71>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   emp[['ename','job','hiredate']][emp['job'] == 'SALESMAN'][emp['hiredate'].between('1981-01-01','1981-12-31')]
#     ename       job   hiredate
# 4  MARTIN  SALESMAN 1981-09-10
# 5   ALLEN  SALESMAN 1981-02-11
# 6  TURNER  SALESMAN 1981-08-21
# 8    WARD  SALESMAN 1981-02-23

# %%
result = emp[['ename','job','hiredate']][emp['hiredate'].between('1981-01-01','1989-12-31')]
result[emp['job'] == 'SALESMAN']
# Out:
# <ipython-input-33-a9f0703895e1>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result[emp['job'] == 'SALESMAN']
#     ename       job   hiredate
# 4  MARTIN  SALESMAN 1981-09-10
# 5   ALLEN  SALESMAN 1981-02-11
# 6  TURNER  SALESMAN 1981-08-21
# 8    WARD  SALESMAN 1981-02-23

# %%
import pandas as pd

tit = pd.read_csv("/content/drive/MyDrive/data100/train.csv")
tit.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tit['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
emp['job'][emp['deptno'] == 20 ].unique()
# Out:
# array(['MANAGER', 'ANALYST', 'CLERK'], dtype=object)

# %%
emp20['age'][emp20['telecom'] != 'lg'].unique()
# Out:
# array([31, 28, 29, 25, 34, 35, 30, 27, 26, 33, 37])

# %%
emp20['age'][emp20.telecom.isin(['sk','kt'])].unique()
# Out:
# array([31, 28, 29, 25, 34, 35, 30, 27, 26, 33, 37])

# %%
emp20.telecom.str.upper()
# Out:
# 0     KT
# 1     SK
# 2     SK
# 3     SK
# 4     KT
# 5     SK
# 6     SK
# 7     SK
# 8     SK
# 9     SK
# 10    KT
# 11    SK
# 12    KT
# 13    SK
# 14    SK
# 15    SK
# 16    KT
# 17    KT
# 18    KT
# 19    LG
# 20    SK
# Name: telecom, dtype: object

# %%
emp20['telecom'] = emp20['telecom'].str.upper()
emp20[['ename','telecom']]
# Out:
#    ename telecom
# 0    홍길동      KT
# 1    이순신      SK
# 2    정약용      SK
# 3    김유신      SK
# 4    장보고      KT
# 5    정몽주      SK
# 6    문익점      SK
# 7     황희      SK
# 8    한석봉      SK
# 9    황진이      SK
# 10   안중근      KT
# 11   김옥균      SK
# 12   윤동주      KT
# 13   안창호      SK
# 14   김좌진      SK
# 15   김두한      SK
# 16    논개      KT
# 17    최영      KT
# 18   김부식      KT
# 19   장영실      LG
# 20   김홍도      SK

# %%
emp20 = pd.read_csv('/content/drive/MyDrive/data100/emp20.csv', encoding = 'euckr')
emp20
# Out:
#     empno ename  age telecom   major   address
# 0       1   홍길동   31      kt    경영학과    인천시 서구
# 1       2   이순신   28      sk  독어독문학과   서울시 양천구
# 2       3   정약용   29      sk    경제학과   서울시 마포구
# 3       4   김유신   31      sk     수학과   경기도 화성시
# 4       5   장보고   25      kt  국제관계학과   경기도 하남시
# 5       6   정몽주   34      sk  컴퓨터공학과   경기도 성남시
# 6       7   문익점   35      sk    행정학과   서울시 용산구
# 7       8    황희   30      sk   중국어학과   서울시 도봉구
# 8       9   한석봉   35      sk    물리학과   경기도 부천시
# 9      10   황진이   27      sk    행정학과   경기도 안산시
# 10     11   안중근   26      kt    경영학과   서울시 관악구
# 11     12   김옥균   30      sk    경영학과   서울시 서초구
# 12     13   윤동주   26      kt  컴퓨터정보과   서울시 서초구
# 13     14   안창호   28      sk    유아교육   서울시 서초구
# 14     15   김좌진   25      sk  정보전기전자   서울시 중랑구
# 15     16   김두한   26      sk    의상학과   서울시 송파구
# 16     17    논개   30      kt     사학과   서울시 강서구
# 17     18    최영   31      kt   생명공학과   경기도 안성시
# 18     19   김부식   33      kt    건축학과  경기도 성남시
# 19     20   장영실   33      lg  지적정보학과  경기도 성남시
# 20     21   김홍도   37      sk  문화콘텐츠과   경기도 하남시

# %%
pd.concat([emp20.ename, emp20.telecom.str.upper()], axis = 1)
# Out:
#    ename telecom
# 0    홍길동      KT
# 1    이순신      SK
# 2    정약용      SK
# 3    김유신      SK
# 4    장보고      KT
# 5    정몽주      SK
# 6    문익점      SK
# 7     황희      SK
# 8    한석봉      SK
# 9    황진이      SK
# 10   안중근      KT
# 11   김옥균      SK
# 12   윤동주      KT
# 13   안창호      SK
# 14   김좌진      SK
# 15   김두한      SK
# 16    논개      KT
# 17    최영      KT
# 18   김부식      KT
# 19   장영실      LG
# 20   김홍도      SK

# %%
pd.concat([emp.ename.str.lower(), emp.sal], axis = 1)
# Out:
#      ename   sal
# 0     king  5000
# 1    blake  2850
# 2    clark  2450
# 3    jones  2975
# 4   martin  1250
# 5    allen  1600
# 6   turner  1500
# 7    james   950
# 8     ward  1250
# 9     ford  3000
# 10   smith   800
# 11   scott  3000
# 12   adams  1100
# 13  miller  1300

# %%
emp[['ename','sal']][emp.ename.str.lower() == 'scott']
# Out:
#     ename   sal
# 11  SCOTT  3000

# %%
emp.ename.str.capitalize()
# Out:
# 0       King
# 1      Blake
# 2      Clark
# 3      Jones
# 4     Martin
# 5      Allen
# 6     Turner
# 7      James
# 8       Ward
# 9       Ford
# 10     Smith
# 11     Scott
# 12     Adams
# 13    Miller
# Name: ename, dtype: object

# %%
pd.concat([emp20.ename, emp20.telecom.str.capitalize()],axis = 1)
# Out:
#    ename telecom
# 0    홍길동      Kt
# 1    이순신      Sk
# 2    정약용      Sk
# 3    김유신      Sk
# 4    장보고      Kt
# 5    정몽주      Sk
# 6    문익점      Sk
# 7     황희      Sk
# 8    한석봉      Sk
# 9    황진이      Sk
# 10   안중근      Kt
# 11   김옥균      Sk
# 12   윤동주      Kt
# 13   안창호      Sk
# 14   김좌진      Sk
# 15   김두한      Sk
# 16    논개      Kt
# 17    최영      Kt
# 18   김부식      Kt
# 19   장영실      Lg
# 20   김홍도      Sk

# %%
emp.ename.str.slice(start = 0, stop = 2)
# Out:
# 0     KI
# 1     BL
# 2     CL
# 3     JO
# 4     MA
# 5     AL
# 6     TU
# 7     JA
# 8     WA
# 9     FO
# 10    SM
# 11    SC
# 12    AD
# 13    MI
# Name: ename, dtype: object

# %%
emp20 = pd.read_csv('/content/drive/MyDrive/data100/emp20.csv', encoding = 'euckr')
emp20[['ename','age']][emp20['ename'].str.slice(start=0, stop=1) == '김']
# Out:
#    ename  age
# 3    김유신   31
# 11   김옥균   30
# 14   김좌진   25
# 15   김두한   26
# 18   김부식   33
# 20   김홍도   37

# %%
emp20[['ename','age','address']][emp20.address.str.slice(start=0, stop=3) != '서울시'].sort_values(by = "age", ascending = False)
# Out:
#    ename  age   address
# 20   김홍도   37   경기도 하남시
# 8    한석봉   35   경기도 부천시
# 5    정몽주   34   경기도 성남시
# 18   김부식   33  경기도 성남시
# 19   장영실   33  경기도 성남시
# 0    홍길동   31    인천시 서구
# 3    김유신   31   경기도 화성시
# 17    최영   31   경기도 안성시
# 9    황진이   27   경기도 안산시
# 4    장보고   25   경기도 하남시

# %%
emp['len'] = emp['ename'].str.len()
emp[['ename','len']].sort_values(by = 'len', ascending = False)
# Out:
#      ename  len
# 4   MARTIN    6
# 6   TURNER    6
# 13  MILLER    6
# 1    BLAKE    5
# 2    CLARK    5
# 3    JONES    5
# 5    ALLEN    5
# 7    JAMES    5
# 10   SMITH    5
# 11   SCOTT    5
# 12   ADAMS    5
# 0     KING    4
# 8     WARD    4
# 9     FORD    4

# %%
tit['len'] = tit.Name.str.len()
tit[['Name','len']].sort_values(by = 'len', ascending = False)
# Out:
#                                                   Name  len
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...   82
# 427  Phillips, Miss. Kate Florence ("Mrs Kate Louis...   67
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...   65
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...   61
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...   57
# ..                                                 ...  ...
# 509                                     Lang, Mr. Fang   14
# 169                                      Ling, Mr. Lee   13
# 74                                       Bing, Mr. Lee   13
# 692                                       Lam, Mr. Ali   12
# 826                                       Lam, Mr. Len   12
#
# [891 rows x 2 columns]

# %%
emp[['ename','sal']][emp['ename'].str.find('M') != -1]
# Out:
#      ename   sal
# 4   MARTIN  1250
# 7    JAMES   950
# 10   SMITH   800
# 12   ADAMS  1100
# 13  MILLER  1300

# %%
emp[['ename','sal']][emp['ename'].str.find('M') == -1]
# Out:
#      ename   sal
# 0     KING  5000
# 1    BLAKE  2850
# 2    CLARK  2450
# 3    JONES  2975
# 5    ALLEN  1600
# 6   TURNER  1500
# 8     WARD  1250
# 9     FORD  3000
# 11   SCOTT  3000

# %%
emp['sal'] = emp['sal'].astype(str)
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       13 non-null     float64
#  4   hiredate  14 non-null     datetime64[ns]
#  5   sal       14 non-null     object
#  6   comm      4 non-null      float64
#  7   deptno    14 non-null     int64
#  8   len       14 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 1.1+ KB

# %%
emp['sal_re'] = emp.sal.str.replace('0','*')
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       13 non-null     float64
#  4   hiredate  14 non-null     datetime64[ns]
#  5   sal       14 non-null     object
#  6   comm      4 non-null      float64
#  7   deptno    14 non-null     int64
#  8   len       14 non-null     int64
#  9   sal_re    14 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 1.2+ KB

# %%
emp[['ename','sal_re']]
# Out:
#      ename sal_re
# 0     KING   5***
# 1    BLAKE   285*
# 2    CLARK   245*
# 3    JONES   2975
# 4   MARTIN   125*
# 5    ALLEN   16**
# 6   TURNER   15**
# 7    JAMES    95*
# 8     WARD   125*
# 9     FORD   3***
# 10   SMITH    8**
# 11   SCOTT   3***
# 12   ADAMS   11**
# 13  MILLER   13**

# %%
import re #데이터 전처리 전문 모듈

emp['sal_star'] = emp.sal.apply(lambda x:re.sub ('[0-3]', '*', x) )
emp[['ename','sal_star']]
# Out:
#      ename sal_star
# 0     KING     5***
# 1    BLAKE     *85*
# 2    CLARK     *45*
# 3    JONES     *975
# 4   MARTIN     **5*
# 5    ALLEN     *6**
# 6   TURNER     *5**
# 7    JAMES      95*
# 8     WARD     **5*
# 9     FORD     ****
# 10   SMITH      8**
# 11   SCOTT     ****
# 12   ADAMS     ****
# 13  MILLER     ****

# %%
result = emp.groupby('job')['empno'].count().reset_index()
result.columns = ['직업', '인원 수']
result[:][result['인원 수'] >= 3]
# Out:
#          직업  인원 수
# 1     CLERK     4
# 2   MANAGER     3
# 4  SALESMAN     4

# %%
emp.groupby(['deptno','job'])['sal'].sum().reset_index()
# Out:
#    deptno        job               sal
# 0      10      CLERK              1300
# 1      10    MANAGER              2450
# 2      10  PRESIDENT              5000
# 3      20    ANALYST          30003000
# 4      20      CLERK           8001100
# 5      20    MANAGER              2975
# 6      30      CLERK               950
# 7      30    MANAGER              2850
# 8      30   SALESMAN  1250160015001250

# %%
emp20.address.str.slice(start=0,stop=3)
# Out:
# 0     인천시
# 1     서울시
# 2     서울시
# 3     경기도
# 4     경기도
# 5     경기도
# 6     서울시
# 7     서울시
# 8     경기도
# 9     경기도
# 10    서울시
# 11    서울시
# 12    서울시
# 13    서울시
# 14    서울시
# 15    서울시
# 16    서울시
# 17    경기도
# 18    경기도
# 19    경기도
# 20    경기도
# Name: address, dtype: object

# %%
emp20['address2'] = emp20.address.str.slice(start=0,stop=3)

# %%
emp20
# Out:
#     empno ename  age telecom   major   address address2
# 0       1   홍길동   31      kt    경영학과    인천시 서구      인천시
# 1       2   이순신   28      sk  독어독문학과   서울시 양천구      서울시
# 2       3   정약용   29      sk    경제학과   서울시 마포구      서울시
# 3       4   김유신   31      sk     수학과   경기도 화성시      경기도
# 4       5   장보고   25      kt  국제관계학과   경기도 하남시      경기도
# 5       6   정몽주   34      sk  컴퓨터공학과   경기도 성남시      경기도
# 6       7   문익점   35      sk    행정학과   서울시 용산구      서울시
# 7       8    황희   30      sk   중국어학과   서울시 도봉구      서울시
# 8       9   한석봉   35      sk    물리학과   경기도 부천시      경기도
# 9      10   황진이   27      sk    행정학과   경기도 안산시      경기도
# 10     11   안중근   26      kt    경영학과   서울시 관악구      서울시
# 11     12   김옥균   30      sk    경영학과   서울시 서초구      서울시
# 12     13   윤동주   26      kt  컴퓨터정보과   서울시 서초구      서울시
# 13     14   안창호   28      sk    유아교육   서울시 서초구      서울시
# 14     15   김좌진   25      sk  정보전기전자   서울시 중랑구      서울시
# 15     16   김두한   26      sk    의상학과   서울시 송파구      서울시
# 16     17    논개   30      kt     사학과   서울시 강서구      서울시
# 17     18    최영   31      kt   생명공학과   경기도 안성시      경기도
# 18     19   김부식   33      kt    건축학과  경기도 성남시       경기도
# 19     20   장영실   33      lg  지적정보학과  경기도 성남시       경기도
# 20     21   김홍도   37      sk  문화콘텐츠과   경기도 하남시      경기도

# %%
emp20.groupby(['address2'])['ename'].count().reset_index()
# Out:
#   address2  ename
# 0      경기도      9
# 1      서울시     11
# 2      인천시      1

# %%
emp20.groupby(['telecom', 'address2'])['ename'].count().reset_index()
# Out:
#   telecom address2  ename
# 0      kt      경기도      3
# 1      kt      서울시      3
# 2      kt      인천시      1
# 3      lg      경기도      1
# 4      sk      경기도      5
# 5      sk      서울시      8

# %%
emp['순위'] = emp['sal'].rank(ascending = False).astype(int)
emp[['ename','sal','순위']].sort_values(by = '순위', ascending=True)
# Out:
#      ename   sal  순위
# 7    JAMES   950   1
# 10   SMITH   800   2
# 0     KING  5000   3
# 9     FORD  3000   4
# 11   SCOTT  3000   4
# 3    JONES  2975   6
# 1    BLAKE  2850   7
# 2    CLARK  2450   8
# 5    ALLEN  1600   9
# 6   TURNER  1500  10
# 13  MILLER  1300  11
# 4   MARTIN  1250  12
# 8     WARD  1250  12
# 12   ADAMS  1100  14

# %%
emp20['순위'] = emp20['age'].rank(method='dense', ascending = False).astype(int)
emp20[['ename', 'age', '순위']].sort_values(by='순위')
# Out:
#    ename  age  순위
# 20   김홍도   37   1
# 8    한석봉   35   2
# 6    문익점   35   2
# 5    정몽주   34   3
# 18   김부식   33   4
# 19   장영실   33   4
# 17    최영   31   5
# 0    홍길동   31   5
# 3    김유신   31   5
# 11   김옥균   30   6
# 16    논개   30   6
# 7     황희   30   6
# 2    정약용   29   7
# 13   안창호   28   8
# 1    이순신   28   8
# 9    황진이   27   9
# 12   윤동주   26  10
# 15   김두한   26  10
# 10   안중근   26  10
# 4    장보고   25  11
# 14   김좌진   25  11
